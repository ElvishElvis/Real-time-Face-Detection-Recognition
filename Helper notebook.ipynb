# %%
import pandas as pd
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
#display the image in dataset

data = pd.read_csv('labeled_pics.csv', index_col=0)
img=np.array(eval(data['img'][-3]))

plt.imshow(img)

# %%
#get the 512-features in the dataset
data = pd.read_csv('labeled_pics.csv', index_col=0)
img=data['features'][-3]
img=eval(img)

# %%
#compare the 512-features with all the features the dataset
data = pd.read_csv('labeled_pics.csv', index_col=0)
results = data['features'].apply(lambda x: np.sqrt(np.sum(np.square(np.subtract(eval(x), img))) if x != '[]' else sys.float_info.max))
results
# Out:
# name
# Joey           0.298476
# Daisy          0.322449
# Xuege          0.296568
# Joy            0.275900
# Elaine         0.352623
# Weiran         0.314469
# Tony           0.273180
# Qinhao         0.328657
# qingran        0.341176
# Yufei          0.366381
# Yabo           0.294531
# huangxinyi     0.462428
# Amber          0.226572
# KD             0.408029
# Yu-Chieh       0.163519
# Roy            0.320202
# Yuki           0.339150
# snow           0.321993
# pengyucheng    0.279575
# Jiayou         0.238995
# Ziwen          0.435375
# yeyifei        0.339376
# Ethan          0.360912
# luxiang        0.328590
# Zhaoyue        0.407255
# Zhuoyuan       0.414321
# Harry          0.262311
# Yiwen          0.346136
# Mingjie        0.450718
# TonyZ          0.378031
# Minqi          0.258972
# fanmingxuan    0.359441
# Elvis          0.377713
# Elvis          0.414319
# Elvis          0.391495
# Elvis          0.430372
# Elaine         0.447121
# Joy1           0.315796
# Joy2           0.317460
# Joy3           0.462719
# Joy4           0.253812
# Joy5           0.279919
# bradpitt_0     0.438401
# bradpitt_1     0.336086
# bradpitt_3     0.306439
# bradpitt_2     0.375426
# bg_4           0.350545
# mj_0           0.329913
# bg_0           0.306488
# em_2           0.348804
# bg_1           0.376404
# mj_1           0.502297
# bg_3           0.383504
# em_1           0.321181
# em_0           0.000000
# bg_2           0.417590
# mj_2           0.517166
# Name: features, dtype: float64
